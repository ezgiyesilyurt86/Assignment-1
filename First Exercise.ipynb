# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ezgi Yesilyurt**
# Assistant Professor

# %% [markdown]
# *I am interested in data science because I would like learn more about programming which will be helpful for my research*

# %% [markdown]
# ### my code provides an instruction(s) to the machine to carry out a simple addition task

# %%
5+6
# Out:
# 11

# %% [markdown]
# To learn more about cats, please click on the following [link](https://en.wikipedia.org/wiki/Cat)
#
# | Cat/Dog | Common Features | Differences |
# | --- | --- | --- |
# | - | Friendly | Cats can be more jealous |
#
# 1. Cats are friendly
# 2. Cats may be jealous
#     * Cats show jealousy when you spend more time on your phone
